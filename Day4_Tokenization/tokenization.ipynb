# %%
import spacy

# %%
ny = nlp('''"Let's go to N.Y.!"''')
for word in ny:
  print(word)
# Out:
# "
# Let
# 's
# go
# to
# N.Y.
# !
# "

# %%
nlp = spacy.blank("en")
doc = nlp("Dr. Strange loves brisket because he's been to Richardson, Frisco, etc. so he is a native texan")

# %%
for token in doc:
  print(token)
# Out:
# Dr.
# Strange
# loves
# brisket
# because
# he
# 's
# been
# to
# Richardson
# ,
# Frisco
# ,
# etc
# .
# so
# he
# is
# a
# native
# texan

# %%
doc[2]
# Out:
# loves

# %%
type(nlp)
# Out:
# spacy.lang.en.English

# %%
type(token)
# Out:
# spacy.tokens.token.Token

# %%
hi = doc[1:5]
hi
# Out:
# Strange loves brisket because

# %%
type(hi)
# Out:
# spacy.tokens.span.Span
